# %%
from selenium import webdriver

# %%
from selenium.webdriver.common.by import By

# %%
from selenium.webdriver.chrome.options import Options

# %%
chrome_options = Options()

# %%
chrome_options.add_argument('--no-sandbox')

# %%
chrome_options.add_argument("--single-process")

# %%
chrome_options.add_argument("--disable-dev-shm-usage")

# %%
chrome_options.add_argument('--headless')

# %%
driver = webdriver.Chrome(options=chrome_options)

# %%
url = 'https://mungmung.kr'

# %%
driver.get(url)

# %%
html = driver.page_source
print(html)
# Out:
# <html><head><script type="text/javascript" id="www-widgetapi-script" src="https://www.youtube.com/s/player/e50626d8/www-widgetapi.vflset/www-widgetapi.js" async=""></script><script src="https://www.youtube.com/iframe_api?v=3.3.9" id="YTAPI"></script>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <title>🐾자 멍멍쌤 홈</title>
#
#     <link href="/css/app.css" rel="stylesheet">
#     <link href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css" rel="stylesheet">
#     <script src="https://code.jquery.com/jquery-latest.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery.mb.YTPlayer/3.3.9/jquery.mb.YTPlayer.min.js"></script>
#     <script src="/js/app.js"></script>
#     <link rel="shortcut icon" href="/favicon/favicon.ico">
#     <link rel="apple-touch-icon" sizes="57x57" href="/favicon/apple-icon-57x57.png">
#     <link rel="apple-touch-icon" sizes="60x60" href="/favicon/apple-icon-60x60.png">
#     <link rel="apple-touch-icon" sizes="72x72" href="/favicon/apple-icon-72x72.png">
#     <link rel="apple-touch-icon" sizes="76x76" href="/favicon/apple-icon-76x76.png">
#     <link rel="apple-touch-icon" sizes="114x114" href="/favicon/apple-icon-114x114.png">
#     <link rel="apple-touch-icon" sizes="120x120" href="/favicon/apple-icon-120x120.png">
#     <link rel="apple-touch-icon" sizes="144x144" href="/favicon/apple-icon-144x144.png">
#     <link rel="apple-touch-icon" sizes="152x152" href="/favicon/apple-icon-152x152.png">
#     <link rel="apple-touch-icon" sizes="180x180" href="/favicon/apple-icon-180x180.png">
#     <link rel="icon" type="image/png" sizes="192x192" href="/favicon/android-icon-192x192.png">
#     <link rel="icon" type="image/png" sizes="32x32" href="/favicon/favicon-32x32.png">
#     <link rel="icon" type="image/png" sizes="96x96" href="/favicon/favicon-96x96.png">
#     <link rel="icon" type="image/png" sizes="16x16" href="/favicon/favicon-16x16.png">
#     <link rel="manifest" href="/favicon/manifest.json">
#     <meta name="msapplication-TileColor" content="#ffffff">
#     <meta name="msapplication-TileImage" content="/favicon/ms-icon-144x144.png">
# </head>
#
# <body topmargin="0" leftmargin="0" marginwidth="0" marginheight="0" style="box-sizing: border-box;"><div id="wrapper_background" class="mbYTP_wrapper" style="position: fixed; z-index: 0; min-width: 100%; min-height: 100%; left: 0px; top: 0px; overflow: hidden; opacity: 1; background-image: none; transition-property: opacity; transition-duration: 1000ms;"><iframe id="iframe_background" class="playerBox" style="position: absolute; z-index: 0; width: 1707px; height: 960px; top: 0px; left: 0px; overflow: hidden; opacity: 1; user-select: none; margin-top: -90px; margin-left: -461px; max-width: initial;" frameborder="0" allowfullscreen="1" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" title="Beauty Of Nature | Stars | Beach | Mountains | Drone View | Stock Footages - No Copyright" width="640" height="360" src="https://www.youtube-nocookie.com/embed/?modestbranding=1&amp;autoplay=0&amp;controls=0&amp;showinfo=0&amp;rel=0&amp;enablejsapi=1&amp;version=3&amp;playerapiid=iframe_background&amp;origin=https%3A%2F%2Fmungmung.kr&amp;allowfullscreen=true&amp;wmode=transparent&amp;iv_load_policy=3&amp;cc_load_policy=0&amp;playsinline=0&amp;html5=1&amp;widgetid=1" unselectable="on"></iframe><div class="YTPOverlay" style="position: absolute; top: 0px; left: 0px; width: 100%; height: 100%;"></div></div>
#     <div id="background" class="player mb_YTPlayer isMuted" data-property="{
#             videoURL: 'https://youtu.be/10X1siLTuac',
#             mute: true,
#             showControls: false,
#             useOnMobile: true,
#             quality: 'highres',
#             containment: 'body',
#             loop: true,
#             autoPlay: true,
#             stopMovieOnBlur: false,
#             startAt: 0,
#             opacity: 1
#         }" style="display: none; position: relative;">
#     </div>
#
#     <div style="left: 0px; width: 100%; position: relative;">
#         <table border="0" width="100%" cellspacing="0" cellpadding="0">
#             <tbody><tr>
#                 <td class="p_title">
#                     &nbsp;🐾자 멍멍쌤의 취미생활<br>
#                 </td>
#                 <td align="center" valign="bottom" class="p_title1">
#                     <div class="visit">
#                         <font size="4" color="white">
#                             오늘:77, 어제:104, 전체:120758 (since 2003)
#                         </font>
#                         </div>
#                 </td>
#                 <td valign="bottom" class="p_title1">
#                                             <div class="hidden top-0 right-0 px-6 py-0 sm:block">
#                                                             <a href="https://mungmung.kr/login" class="text-sm text-gray-700 dark:text-gray-500 ">🐾1</a>
#                                                     </div>
#                                     </td>
#                 <td align="right" valign="bottom" class="p_title1">
#                     <a href="https://photo.mungmung.kr/port/port.php" target="_Blank">추억의 취미 작품집
#                         보기</a>&nbsp;&nbsp;&nbsp;<br>
#                 </td>
#                 <td align="right" valign="bottom" class="p_title1">
#                     <a href="https://old.mungmung.kr/rb/?r=home" target="_Blank">옛날 멍멍홈 방문</a>&nbsp;&nbsp;&nbsp;<br>
#                 </td>
#             </tr>
#         </tbody></table>
#     </div>
#
#     <p style="position: relative;"><br></p>
#
#     <div class="p_new" style="left: 0px; width: 100%; position: relative;">
#     <br>
#     <table border="0" width="90%" align="center">
#         <tbody><tr>
#             <td>
#                 <p align="center" class="p_title">
#                     <b>
#                         &lt; 최근 업그레이드 현황&gt;
#                     </b>
#                 </p>
#             </td>
#         </tr>
#     </tbody></table>
#     <table border="0" width="90%" align="center">
#         <tbody><tr>
#             <td>&nbsp;</td>
#         </tr>
#         <tr>
#             <td style="text-indent:-3em; padding:10px 10px 10px 60px;">
#                             </td>
#         </tr>
#         <tr>
#             <td>&nbsp;</td>
#         </tr>
#     </tbody></table>
# </div>
#
#     <p style="position: relative;"><br></p>
#
#
#
#         <div class="p1" style="left: 0px; width: 100%; position: relative;">
#     <br>
#     <table border="0" cellspacing="0" cellpadding="0" width="90%" align="center" class="aa">
#         <tbody><tr>
#             <td>
#                 <p align="center" class="p_title">
#                     <b>
#                         웹을 이용한 유틸들
#                     </b>
#                 </p>
#             </td>
#         </tr>
#     </tbody></table>
#     <table border="0" width="90%" align="center">
#         <tbody><tr>
#             <td>&nbsp;</td>
#         </tr>
#         <tr>
#             <td style="text-indent:-3em; padding:10px 10px 10px 60px;">
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/104" target="_Blank" class="data" idx="1_1">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     학부모 상담 예약 시스템 (2023학년도 1학기 운영 시작) V2.0 (2023-02-20)
#                         </a>
#
#                                                     <a href="https://youtu.be/PoLoiscfgMo" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 학부모 상담 예약을 편리하게 받을 수 있는 웹사이트
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/122" target="_Blank" class="data" idx="1_2">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     (새시스템용)분반(4.1)+일일교육(3.1)+예약(2.3)통합프로그램(이번에는 예약시스템만 업데이트됨) V. (2023-01-06)
#                         </a>
#
#                                                 =&gt; 예약 프로그램 시간 추가
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/111" target="_Blank" class="data" idx="1_3">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     (새시스템용)분반(4.1)+일일교육(3.1)+예약(2.2)통합프로그램(이번에는 예약시스템만 업데이트됨 V (2022-07-09)
#                         </a>
#
#                                                     <a href="https://youtu.be/5zyyo97DQNk" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 분반 작업 시간 최소화, 일일교육 관리, 각종 예약 관리
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/category/외워쓰기" target="_Blank" class="data" idx="1_4">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     웹을 이용한 외워쓰기(받아쓰기) 1학년 2학기용, 2학년 1,2학기용 V1.0 (2021-08-24)
#                         </a>
#
#                                                 =&gt; 웹을 이용한 스스로 할 수 있는 외워쓰기(받아쓰기) 시스템
#                     </p>
#                                 <br>
#             </td>
#         </tr>
#     </tbody></table>
# </div>
#
#         <p style="position: relative;"><br></p>
#
#
#         <div class="p2" style="left: 0px; width: 100%; position: relative;">
#     <br>
#     <table border="0" cellspacing="0" cellpadding="0" width="90%" align="center" class="aa">
#         <tbody><tr>
#             <td>
#                 <p align="center" class="p_title">
#                     <b>
#                         학급 유틸 프로그램
#                     </b>
#                 </p>
#             </td>
#         </tr>
#     </tbody></table>
#     <table border="0" width="90%" align="center">
#         <tbody><tr>
#             <td>&nbsp;</td>
#         </tr>
#         <tr>
#             <td style="text-indent:-3em; padding:10px 10px 10px 60px;">
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/126" target="_Blank" class="data" idx="2_1">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     이름표 프로그램(이름=&gt;표,낙관,QR 만들어 주는 프로그램)(stamp) V1.0 (2023-02-15)
#                         </a>
#
#                                                     <a href="https://youtu.be/Z5RW-yyrG1M" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 명단을 표,낙관,QR로 만들어 주는 프로그램
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/127" target="_Blank" class="data" idx="2_2">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     바탕화면 아이콘 숨기기 프로그램(hideicon) V1.0 (2023-02-15)
#                         </a>
#
#                                                     <a href="https://youtu.be/wBVP3DNlUoI" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 바탕화면 아이콘을 잠시 숨겨주는 프로그램
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/124" target="_Blank" class="data" idx="2_3">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     PC음성인식키보드(VoiceTypingForPc) V1.0 (2023-01-28)
#                         </a>
#
#                                                     <a href="https://youtu.be/Bm21rSqiF1o" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 안드로이드 폰을 이용하여 Windows pc의 모든 프로그램에 직접 음성으로 글을 입력할 수 있음.
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/103" target="_Blank" class="data" idx="2_4">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     화면돋보기 V1.0 (2021-12-05)
#                         </a>
#
#                                                 =&gt; 화면 일부분을 줌잇의 라이브줌처럼, 하지만 좀더 편리하게 확대 가능
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/101" target="_Blank" class="data" idx="2_5">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     줌(zoom)출석부 V2.0 (2021-11-25)
#                         </a>
#
#                                                     <a href="https://youtu.be/4tYN6RDT8nk" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; zoom 수업 도중에 참가자를 실시간으로 체크해주는 실시간 출석부
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/entry/소리-측정기-발표-측정기" target="_Blank" class="data" idx="2_6">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     소리측정기(발표측정기) V1.0 (2021-11-25)
#                         </a>
#
#                                                     <a href="https://youtu.be/LQ5o6QnxHoI" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 아동의 발표 소리, 교실의 소음도를 측정하여 보여주는 프로그램
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/82" target="_Blank" class="data" idx="2_7">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     가로카메라앱(horizontal camera)-미러링, 무선실물화상기 대용 V3.5 (2021-08-20)
#                         </a>
#
#                                                     <a href="https://youtu.be/VlWIvaHORGo" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 스마트폰을 무선실물화상기처럼, 무조건 가로로 실행
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/83" target="_Blank" class="data" idx="2_8">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     가로카메라앱 전용 뷰어 V1.0 (2021-08-20)
#                         </a>
#
#                                                     <a href="https://youtu.be/VlWIvaHORGo" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 가로카메라앱 전용 뷰어 - 윈조우즈 전용
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/70" target="_Blank" class="data" idx="2_9">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     화면 가리개 V1.7 (2021-05-02)
#                         </a>
#
#                                                     <a href="https://youtu.be/fsw0s32nLyM" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 화면 일부분을 다양한 방법으로 가리거나, 반투명으로 설정
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/1" target="_Blank" class="data" idx="2_10">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     화면 꺼지지 마(nozzz) V1.0 (2020-06-30)
#                         </a>
#
#                                                     <a href="https://youtu.be/AR0375hNmu4" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 화면이 꺼지지 않도록 방지하는 유틸
#                     </p>
#                                 <br>
#             </td>
#         </tr>
#     </tbody></table>
# </div>
#
#         <p style="position: relative;"><br></p>
#
#
#         <div class="p3" style="left: 0px; width: 100%; position: relative;">
#     <br>
#     <table border="0" cellspacing="0" cellpadding="0" width="90%" align="center" class="aa">
#         <tbody><tr>
#             <td>
#                 <p align="center" class="p_title">
#                     <b>
#                         NEIS Util
#                     </b>
#                 </p>
#             </td>
#         </tr>
#     </tbody></table>
#     <table border="0" width="90%" align="center">
#         <tbody><tr>
#             <td>&nbsp;</td>
#         </tr>
#         <tr>
#             <td style="text-indent:-3em; padding:10px 10px 10px 60px;">
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/107" target="_Blank" class="data" idx="3_1">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     나이스 입력 도우미 통합본-탭5번 추가 V3.1 (2022-04-01)
#                         </a>
#
#                                                     <a href="https://youtu.be/HXi6Ws5UGSg" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 기존 나이스 입력 유틸 프로그램 통합, 복사 입력 지원
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/110" target="_Blank" class="data" idx="3_2">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     NEIS 접속 도우미 - 엣지(Edge)용, EVPN 접속 가능 V2.0 (2022-01-28)
#                         </a>
#
#                                                 =&gt; 나이스 접속시 아이디를 자동으로 입력시켜주는 단순한 유틸, 부팅시 자동 실행 지원
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/109" target="_Blank" class="data" idx="3_3">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     나이스 초등 신입생(1학년) 주소 변환 프로그램 V1.0 (2022-01-27)
#                         </a>
#
#                                                     <a href="https://youtu.be/flRGkXyHcMM" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 초등 신입생(1학년) 입학대상자 주소변환 기능 제대로 활용하기
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/108" target="_Blank" class="data" idx="3_4">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     탭매크로 프로그램 V1.0 (2022-01-27)
#                         </a>
#
#                                                     <a href="https://youtu.be/z_JK7-c1Xvc" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 엑셀과 연동하여 나이스, 기타 다른 곳에 입력을 자동화시킴
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/72" target="_Blank" class="data" idx="3_5">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     자가진단 자동로그인 프로그램 V3.0 (2021-06-24)
#                         </a>
#
#                                                 =&gt; 교사용 자가진단시스템 자동 로그인
#                     </p>
#                                 <br>
#             </td>
#         </tr>
#     </tbody></table>
# </div>
#
#         <p style="position: relative;"><br></p>
#
#
#         <div class="p4" style="left: 0px; width: 100%; position: relative;">
#     <br>
#     <table border="0" cellspacing="0" cellpadding="0" width="90%" align="center" class="aa">
#         <tbody><tr>
#             <td>
#                 <p align="center" class="p_title">
#                     <b>
#                         메모장 및 윈도우 창 관련 유틸
#                     </b>
#                 </p>
#             </td>
#         </tr>
#     </tbody></table>
#     <table border="0" width="90%" align="center">
#         <tbody><tr>
#             <td>&nbsp;</td>
#         </tr>
#         <tr>
#             <td style="text-indent:-3em; padding:10px 10px 10px 60px;">
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/114" target="_Blank" class="data" idx="4_1">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     항상 위 (AlwaysOnTop, 메모장, 기타 어떤 프로그램이든...) 종합판 V1.0 (2022-02-26)
#                         </a>
#
#                                                     <a href="https://youtu.be/dk-HkjWMW_8" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 메모장 또는 어떠한 프로그램이든 항상위로 만들어 주는 프로그램들 5가지
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/105" target="_Blank" class="data" idx="4_2">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     윈도우 자체에서 메모장 항상 위 구현 V1.0 (2022-01-17)
#                         </a>
#
#                                                 =&gt; 다운로드, usb 복사 등이 필요없어 보안이 중요한 회사에서도 활용 가능-엑셀 또는 파워셀(PowerShell) 활용
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/61" target="_Blank" class="data" idx="4_3">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     작업메모장 항상 위 V2.0 (2021-03-11)
#                         </a>
#
#                                                 =&gt; 미리 저장해둔 있는 작업.txt 파일을 항상위 속성으로 열어줌.
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/69" target="_Blank" class="data" idx="4_4">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     항상위로 V1.0 (2021-02-14)
#                         </a>
#
#                                                 =&gt; 원하는 실행파일을 항상위 속성으로 열 수 있게 함.
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/17" target="_Blank" class="data" idx="4_5">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     멍메모장 V2.0 (2020-08-02)
#                         </a>
#
#                                                     <a href="https://youtu.be/JgnqNxA532M" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 메모장이지만, 글씨체, 크기, 글씨를 바꿀 수 있고, 테두리가 없는 넓은 메모장
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/17" target="_Blank" class="data" idx="4_6">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     To.멍메모장 프로그램 V2.0 (2020-08-02)
#                         </a>
#
#                                                     <a href="https://youtu.be/tvy2tseB1Mc" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 멍메모장에 한글자 한글자 타자를 치듯 입력되는 효과를 나타낼 수 있음
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/12" target="_Blank" class="data" idx="4_7">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     창문 관리 프로그램 V1.3 (2020-07-29)
#                         </a>
#
#                                                 =&gt; 열려있는 프로그램 창들을 선택적으로 항상위, 모니터 이동, 투명도 조정
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/10" target="_Blank" class="data" idx="4_8">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     메모장 항상 위 V1.0 (2020-07-21)
#                         </a>
#
#                                                 =&gt; 빈 메모장을 열어 항상위 속성으로 실행시켜 다른 창에 가리지 않도록 해줌
#                     </p>
#                                 <br>
#             </td>
#         </tr>
#     </tbody></table>
# </div>
#
#         <p style="position: relative;"><br></p>
#
#
#         <div class="p5" style="left: 0px; width: 100%; position: relative;">
#     <br>
#     <table border="0" cellspacing="0" cellpadding="0" width="90%" align="center" class="aa">
#         <tbody><tr>
#             <td>
#                 <p align="center" class="p_title">
#                     <b>
#                         QR, barcode, NFC 관련 유틸
#                     </b>
#                 </p>
#             </td>
#         </tr>
#     </tbody></table>
#     <table border="0" width="90%" align="center">
#         <tbody><tr>
#             <td>&nbsp;</td>
#         </tr>
#         <tr>
#             <td style="text-indent:-3em; padding:10px 10px 10px 60px;">
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/117" target="_Blank" class="data" idx="5_1">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     BarQrNfcToPc 안드로이드 앱 V1.0 (2022-07-05)
#                         </a>
#
#                                                     <a href="https://youtu.be/_THwTOoqPCc" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 안드로이드 스마트폰을 Barcode, QR, NFC 리더기로 사용할 수 있도록 해줌.
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/118" target="_Blank" class="data" idx="5_2">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     BarQrNfcToPc 윈도우용 프로그램 V2.0 (2022-07-05)
#                         </a>
#
#                                                     <a href="https://youtu.be/_THwTOoqPCc" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 스마트폰에서 Barcode, QR, NFC를 읽어 PC로 전송받는 프로그램
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/119" target="_Blank" class="data" idx="5_3">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     클123QR 프로그램 V5.0 (2022-07-05)
#                         </a>
#
#                                                     <a href="https://youtu.be/4FnQ6JGkdKg" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 학생의 QR코드를 읽어 클래스123에 자동 체크해주는 프로그램
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/106" target="_Blank" class="data" idx="5_4">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     스크린 Ocr Qr V1.2 (2022-01-26)
#                         </a>
#
#                                                     <a href="https://youtu.be/CcvPTu9HLZM" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 화면에 보이는는 모든 것을 텍스트로, 번역도 가능, QR인식, 표는 엑셀로 변환
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/81" target="_Blank" class="data" idx="5_5">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     클456엑셀 프로그램(매크로 파일) V1.0 (2021-08-10)
#                         </a>
#
#                                                     <a href="https://youtu.be/NkEllnHRBDQ" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 클456QR 프로그램과 연동되는 엑셀 체크 프로그램
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/80" target="_Blank" class="data" idx="5_6">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     클456QR 프로그램 V2.0 (2021-08-05)
#                         </a>
#
#                                                     <a href="https://youtu.be/SMyK-006pSk" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 클456엑셀과 연동이 되는 클123QR과 유사한 프로그램
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/79" target="_Blank" class="data" idx="5_7">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     BarQR리더기 V2.1 (2021-08-03)
#                         </a>
#
#                                                     <a href="https://youtu.be/MXv6LpqhV0s" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 컴퓨터에서 바코드, QR코드를 읽어 엑셀로 입력값 전달
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/78" target="_Blank" class="data" idx="5_8">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     작품 촬영기 V1.2 (2021-07-26)
#                         </a>
#
#                                                     <a href="https://youtu.be/y-VBsZ6KSFw" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; QR을 붙인 작품을 컴퓨터에서 읽어들으며 자동으로 파일 이름 설정
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/76" target="_Blank" class="data" idx="5_9">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     QR 일괄 생성기 V1.2 (2021-06-29)
#                         </a>
#
#                                                     <a href="https://youtu.be/ndUwnWd1JFk" target="_Blank"><img src="/images/youtube1.png" width="50" class="inline"></a>
#                                                 =&gt; 학생용 QR코드를 손쉽게 일괄로 생성
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/18" target="_Blank" class="data" idx="5_10">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     멍 QR 생성기 V1.5 (2020-09-07)
#                         </a>
#
#                                                 =&gt; 유튜브 주소 변환, 주소에 대한 QR 생성, QR 읽기 가능
#                     </p>
#                                     <p>
#                         <a href="https://indischool.com/31" target="_Blank" class="data" idx="5_11">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     멍 QR 생성기 v2.0(인디스쿨 로그인 필수) V2.0 (2020-09-07)
#                         </a>
#
#                                                 =&gt; 네이버 단축주소 생성 가능 + 위 1.5버전 기능 포함
#                     </p>
#                                 <br>
#             </td>
#         </tr>
#     </tbody></table>
# </div>
#
#         <p style="position: relative;"><br></p>
#
#
#         <div class="p6" style="left: 0px; width: 100%; position: relative;">
#     <br>
#     <table border="0" cellspacing="0" cellpadding="0" width="90%" align="center" class="aa">
#         <tbody><tr>
#             <td>
#                 <p align="center" class="p_title">
#                     <b>
#                         학교 및 기타 유틸
#                     </b>
#                 </p>
#             </td>
#         </tr>
#     </tbody></table>
#     <table border="0" width="90%" align="center">
#         <tbody><tr>
#             <td>&nbsp;</td>
#         </tr>
#         <tr>
#             <td style="text-indent:-3em; padding:10px 10px 10px 60px;">
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/92" target="_Blank" class="data" idx="6_1">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     Easy WiFi Connector 프로그램 (using QR) V1.0 (2021-10-31)
#                         </a>
#
#                                                 =&gt; WiFi QR을 촬영하면 바로 wifi에 접속이 되는 윈도우즈 프로그램
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/88" target="_Blank" class="data" idx="6_2">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     WiFi QR 생성기 프로그램 V1.0 (2021-10-24)
#                         </a>
#
#                                                 =&gt; WiFi QR 코드를 생성하는 윈도우용 프로그램
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/89" target="_Blank" class="data" idx="6_3">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     Easy WiFi Connector 앱 (using QR) V1.0 (2021-10-24)
#                         </a>
#
#                                                 =&gt; WiFi QR을 촬영하면 바로 wifi에 접속이 되는 안드로이드 앱
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/63" target="_Blank" class="data" idx="6_4">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     Scoman (기자재 관리 프로그램) V1.1 (2021-04-03)
#                         </a>
#
#                                                 =&gt; 교내 컴퓨터의 사양 등을 손쉽게 수집하여 관리할 수 있음.
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/44" target="_Blank" class="data" idx="6_5">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     컴퓨터정보(이름, 작업그룹, 아이피 등..) 수정 프로그램 V1.0 (2021-01-28)
#                         </a>
#
#                                                 =&gt; 교실 컴퓨터정보(이름, 작업그룹, 아이피 등..)을 누구나 손쉽게 바꿀 수 있음.
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs.tistory.com/18" target="_Blank" class="data" idx="6_6">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     경력계산기(엑셀) V1.0 (2020-08-05)
#                         </a>
#
#                                                 =&gt; 경력계산을 해주는 엑셀파일
#                     </p>
#                                 <br>
#             </td>
#         </tr>
#     </tbody></table>
# </div>
#
#         <p style="position: relative;"><br></p>
#
#
#         <div class="p7" style="left: 0px; width: 100%; position: relative;">
#     <br>
#     <table border="0" cellspacing="0" cellpadding="0" width="90%" align="center" class="aa">
#         <tbody><tr>
#             <td>
#                 <p align="center" class="p_title">
#                     <b>
#                         알림 사항
#                     </b>
#                 </p>
#             </td>
#         </tr>
#     </tbody></table>
#     <table border="0" width="90%" align="center">
#         <tbody><tr>
#             <td>&nbsp;</td>
#         </tr>
#         <tr>
#             <td style="text-indent:-3em; padding:10px 10px 10px 60px;">
#                                     <p>
#                         <a href="https://mungkhs1.tistory.com/76" target="_Blank" class="data" idx="7_1">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     (게시글)VSCode를 이용한 서버 SSH 접속 및 원격 도커 제어하기 V. (2023-01-03)
#                         </a>
#
#                                                 =&gt; VSCode를 이용한 서버 SSH 접속 및 원격 도커 제어하기
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs1.tistory.com/77" target="_Blank" class="data" idx="7_2">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     (게시글)리눅스 시스템, 네트워크 모니터링 툴들 V. (2023-01-03)
#                         </a>
#
#                                                 =&gt; top, htop, iftop, nload
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs1.tistory.com/78" target="_Blank" class="data" idx="7_3">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     (게시글)JMeter를 이용한 서버 부하 테스트 방법 V. (2023-01-03)
#                         </a>
#
#                                                 =&gt; JMeter를 이용한 서버 부하 테스트 방법
#                     </p>
#                                     <p>
#                         <a href="https://mungkhs1.tistory.com/75" target="_Blank" class="data" idx="7_4">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     (게시글) 18. 와일드카드 인증서 자동 갱신 (docker + Let's Encrypt + wildcard 인증서 + crontab) V. (2023-01-02)
#                         </a>
#
#                                                 =&gt; 3개월마다 갱신해야 하는 인증서를 자동으로 갱신되도록 하는 방법
#                     </p>
#                                     <p>
#                         <a href="https://indischool.com/boards/announcement/37251001?page=2" target="_Blank" class="data" idx="7_5">
#                             <img src="/images/ball.gif" class="inline">
#                                                                                     요즘 하고 있는 취미생활 V. (2022-10-03)
#                         </a>
#
#                                                 =&gt; 여름방학 부터 당분간 계속 쪼랩(인디스쿨 취미 코딩 커뮤니티)에서 라라벨(laravel) 공부중입니다. 그래서, 잠시 모든 개발을 멈추게 되어습니다. 추후 라라벨 공부가 끝나면 다시 취미 개발을 시작할 예정입니다.
#                     </p>
#                                 <br>
#             </td>
#         </tr>
#     </tbody></table>
# </div>
#
#         <p style="position: relative;"><br></p>
#
#
#
#         <!--레이어 도움말-->
#         <div id="divLayer_1_1" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *학부모 상담 예약을 편리하게 받을 수 있는 웹사이트<br>
#         </div>
#     </div>
#     <div id="divLayer_1_2" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             예약 프로그램 시간 추가
#         </div>
#     </div>
#     <div id="divLayer_1_3" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *각 학교에서 사용하는 일일교육 양식 그대템 사용가능함.<br>*아침에 컴퓨터 부팅시 자동으로 일일교육이 열리게 됨.<br>*특별실 예약 시스템<br>*아주 손쉽게 사용할 수 있는 분반시스템<br>*위 세 시스템은 각각 별도의 시스템으로 1~2개 시스템만 운영도 가능함<br>*(2022.07.09)예약시스템에서 예약가능 특별실(또는 기기) 갯수를 10개에서 무제한으로 늘림.
#         </div>
#     </div>
#     <div id="divLayer_1_4" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *웹을 이용한 외워쓰기(받아쓰기) 시스템<br>*현재 1학년 2학기, 2학년 1학기, 2학기 지원<br>
#         </div>
#     </div>
#
#
#
#         <!--레이어 도움말-->
#         <div id="divLayer_2_1" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             명단을 표,낙관,QR로 만들어 주는 프로그램
#         </div>
#     </div>
#     <div id="divLayer_2_2" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             바탕화면 아이콘을 잠시 숨겨주는 프로그램
#         </div>
#     </div>
#     <div id="divLayer_2_3" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             안드로이드 폰을 이용하여 Windows pc의 모든 프로그램에 직접 음성으로 글을 입력할 수 있음.
#         </div>
#     </div>
#     <div id="divLayer_2_4" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *화면 일부분을 크게 확대시킬 수 있음.<br>*zoomit의 라이브줌과 유사한 기능임.<br>
#         </div>
#     </div>
#     <div id="divLayer_2_5" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *zoom 수업 도중에 참가자를 실시간으로 체크해줌.<br>*입장 시간, 퇴장 시간이 자동 기록됨.<br>*출석 기록을 파일로 저장할 수 있음.<br>*교과선생님의 경우 각반 학생 명단을 즉시 바꿀 수 있음.<br>*결석자 명단 조회<br>
#         </div>
#     </div>
#     <div id="divLayer_2_6" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *아동의 발표 소리의 크기를 색으로 보여줄 수 있음.<br>*교실의 소음도를 측정하여 아이들에게 색으로 보여줄 수 있음.<br>
#         </div>
#     </div>
#     <div id="divLayer_2_7" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *교실에서 TV와 미러링시 무선실물화상기처럼 쓸 수 있음.<br>*미러링 기능 지원<br>*스마트폰 기본 카메라는 세로 모드만 지원해서 화면이 작게 나오지만, 본 앱은 가로 전용으로 TV화면을 꽉차게 사용할 수 있음.<br>*불필요한 버튼이 하나도 없음.<br>*실행도중 화면이 꺼지지 않으며, 화면을 잠시 어둡게 할 수 있음. <br>*화면 정지 기능, 선그리기 기능<br>*줌 기능, 사진 촬영 기능
#         </div>
#     </div>
#     <div id="divLayer_2_8" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *가로카메라앱 전용 뷰어<br>*미러링 신호가 있으면 자동으로 창이 보여지며, 신호가 없으면 자동으로 창이 최소화됨.<br>
#         </div>
#     </div>
#     <div id="divLayer_2_9" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *화면 일부분을 완전히 가리거나, 반투명으로 가릴 수 있음.<br>*가리개의 색깔, 투명도를 조정할 수 있음.<br>*가리개에 그림 삽입이 가능함.<br>*창을 투명하게 하면 창 뒷부분 선택도 가능함.<br>*마우스 hover 기능
#         </div>
#     </div>
#     <div id="divLayer_2_10" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *수업시간에 가만놔두면 3~5분마다 컴퓨터 화면이 꺼지는 것을 방지해 주는 프로그램
#         </div>
#     </div>
#
#
#
#         <!--레이어 도움말-->
#         <div id="divLayer_3_1" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *hwp 파일을 이용한 평어 일괄 입력<br>*간편하게 복사 기능을 이용하여 평어,수행 일괄 입력<br>*엑셀 파일을 이용한 수행평가 결과 일괄 입력<br>*버튼, 숫자키를 이용하여 수행 입력<br>
#         </div>
#     </div>
#     <div id="divLayer_3_2" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *나이스 접속시 아이디를 자동 입력해주고, 인증서 선택창까지 자동으로 열어주어 편리함.<br>
#         </div>
#     </div>
#     <div id="divLayer_3_3" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *초등 신입생(1학년) 입학대상자 주소변환 기능 활용<br>*우편번호, 도로명 주소 자동 변환 <br>*나이스에 자동 입력 지원<br>
#         </div>
#     </div>
#     <div id="divLayer_3_4" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *엑셀과 연동<br>*엑셀과 연동하여 나이스의 입력을 자동화시킴<br>*나이스 뿐만 아니라 다양한 곳에 활용 가능<br>
#         </div>
#     </div>
#     <div id="divLayer_3_5" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *교사용 자가진단시스템에 자동으로 로그인을 해줌.<br>*컴퓨터 부팅시 자동으로 실행을 시킬 수 있어 편리함.<br>*V3.0-더이상 크롬드라이버를 수정으로 업그레이드 할 필요 없습니다.<br>
#         </div>
#     </div>
#
#
#
#         <!--레이어 도움말-->
#         <div id="divLayer_4_1" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             1. 뭐든항상위 (AlwaysOnTopAll) 프로그램<br>2. 특정 프로그램 항상위 (AlwaysOnTop_exe) 프로그램<br>3. 특정 메모장 항상위 (AlwaysOnTop_work) 프로그램<br>4. 메모장 항상위 (AlwaysOnTop_notepad) 프로그램<br>5. 보안 회사, 은행 등 보안 때문에 다운로드, usb 복사 등이 불가능할 때 윈도우 자체에서 항상위 구현<br>
#         </div>
#     </div>
#     <div id="divLayer_4_2" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *다운로드, usb 복사 등이 필요없어 보안이 중요한 회사에서도 활용 가능<br>*엑셀 또는 파워셀(PowerShell) 활용<br>
#         </div>
#     </div>
#     <div id="divLayer_4_3" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *미리 저장해둔 있는 작업.txt 파일을 항상위 속성으로 열어줌.<br>
#         </div>
#     </div>
#     <div id="divLayer_4_4" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *원하는 실행파일을 항상위 속성으로 열 수 있음.<br> (단, 현재는 단일 실행파일만 가능함.)<br>*아래 있는 창문관리 프로그램은 열려있는 창의 속성을 조정하는 것이고, 본 프로그램은 처음부터 실행시킬 때 항상위 속성으로 열리게 하는 것임.<br>
#         </div>
#     </div>
#     <div id="divLayer_4_5" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *제목표시줄과 메뉴, 아래쪽 상태표시줄이 없어 화면을 넓게 사용함.<br>*내용 일부분의 글씨체, 글씨 크기, 글씨 색깔을 수정할 수 있음.<br>*그림 입력이 가능함.<br>*기본으로 항상 위 고정 속성을 가지고 있음.<br>*배경색 변경 및 창 투명도 조정이 가능함.<br>
#         </div>
#     </div>
#     <div id="divLayer_4_6" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *멍메모장에 한글자 한글자 타자를 치듯 입력되는 효과를 나타낼 수 있음.<br>
#         </div>
#     </div>
#     <div id="divLayer_4_7" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *열려있는 프로그램 창들을 선택적으로 항상위로 고정시킬 수 있음.<br>*다중 모니터일 경우 특정 창을 다른 모니터로 즉시 가져올 수 있음.<br>*열려있는 프로그램 창의 투명도를 조정할 수 있음.<br>
#         </div>
#     </div>
#     <div id="divLayer_4_8" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *메모장 프로그램을 항상위 속성으로 실행시켜 다른 창에 가리지 않도록 해줌.<br>
#         </div>
#     </div>
#
#
#
#         <!--레이어 도움말-->
#         <div id="divLayer_5_1" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *사용하지 않는 구형 스마트폰을 리더기로 만들어줌.<br>*블루투스 또는 와이파이 연결로 무선으로 사용 가능함.<br>
#         </div>
#     </div>
#     <div id="divLayer_5_2" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *스마트폰에서 인식된 값을 컴퓨터에서 전송받는 역할을 함.<br>*블루투스 또는 와이파이 연결로 무선으로 사용 가능함.<br>*입력된 값을 엑셀이나 기타 다른 프로그램에 전달해줌.<br>*클123QR 프로그램으로도 값 전송 가능.<br>
#         </div>
#     </div>
#     <div id="divLayer_5_3" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *교실에 있는 실물화상기, 화상캠을 이용하여 학생의 QR코드를 읽으면, 클래스123 사이트의 해당 아동이 자동으로 체크가 됨.<br>*바코드 스캐터(2D 인식이 가능해야 함)<br>*NFC 리더기를 이용하여 NFC 카드 및 태그도 이용 가능<br>*인식시 소리 기능 추가, 항상위 기능 있음<br>*인식 소리로 사용할 녹음기 기능 추가<br>*BarQrNfcToPc 프로그램과 연동 가능함.<br>
#         </div>
#     </div>
#     <div id="divLayer_5_4" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *컴퓨터 모니터(화면)에 보여지는 것을 캡춰하여 OCR 기능을 이용하여 텍스트로 변환시켜줌.<br>*화면에 있는 QR 코드를 바로 인식할 수 있음.<br>*앞에서 텍스트로 인식된 결과를 바로 번역해 볼 수 있음.<br>*V1.2-표 인식 후 엑셀로 변환 가능<br>
#         </div>
#     </div>
#     <div id="divLayer_5_5" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *엑셀 매크로 파일임.<br>*클래스123 같은 체크 프로그램<br>*사진 삽입 가능<br>*버튼 위치 변경 가능<br>
#         </div>
#     </div>
#     <div id="divLayer_5_6" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *클456엑셀과 연동이 됨<br>*클123QR과 유사한 프로그램<br>
#         </div>
#     </div>
#     <div id="divLayer_5_7" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *교실에 있는 실물화상기, 화상캠을 이용하여 QR코드나 바코드를 읽어낼 수 있음.<br>*읽어낸 값을 엑셀이나 한글 파일 등에 자동으로 입력 받을 수 있음.<br>*시간 간격을 두고 연속으로 계속 인식을 시킬 수 있음.<br>*엑셀을 잘 활용하실 수 있다면, 아이들 각각의 QR코드를 생성 후 아이들이 직접 QR코드를 실물화상기에 대어 검사한 사람 기록 표시 등을 할 수 있을 것입니다.<br>
#         </div>
#     </div>
#     <div id="divLayer_5_8" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *교실에 있는 실물화상기, 화상카메라를 이용해 작품을 찍을 수 있음.<br>*사진 촬영 간격 시간을 조정해서 반복적으로 자동으로 사진을 찍을 수 있음. (단, QR코드가 인식되어야만 사진이 촬영됨.)<br>*사진 속 QR코드를 인식하여 자동으로 파일 이름을 만들어줌. (다양한 형태로 이름을 만들 수 있음)<br>*스마트폰으로 찍은 사진(QR코드가 포함된)도 폴더째로 불러들여 자동으로 QR인식을 시킨 후 파일명을 자동적으로 붙여줄 수 있음.<br>
#         </div>
#     </div>
#     <div id="divLayer_5_9" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *학생용 QR코드를 손쉽게 일괄로 생성할 수 있음.<br>
#         </div>
#     </div>
#     <div id="divLayer_5_10" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *유튜브 주소 변환이 가능함.<br>*주소에 대한 QR코드 생성이 가능함.<br>*QR코드에 학교나 개인의 로고 삽입이 가능함.<br>*컴퓨터 문서에 들어있는 QR코드를 스마트폰 촬영이 필요없이 컴퓨터에서 직접 열어볼 수 있음.<br>*컴퓨터 문서에 들어있는 클릭할 수 없는 영문 주소를 읽어낼 수 있음.
#         </div>
#     </div>
#     <div id="divLayer_5_11" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *단축주소 생성기능이 있음.<br>*그 외에는 위 멍QR 1.5버전과 동일한 기능을 가지고 있음.<br>
#         </div>
#     </div>
#
#
#
#         <!--레이어 도움말-->
#         <div id="divLayer_6_1" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *윈도우즈용<br>*WiFi QR을 촬영하면 바로 접속이 가능함.<br>*WiFi 정보를 손쉽게 삭제할 수 있음.<br>
#         </div>
#     </div>
#     <div id="divLayer_6_2" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *WiFi QR을 생성할 수 있음.<br>*QR 코드에 로고 및 설명글을 삽입시킬 수 있음.<br>
#         </div>
#     </div>
#     <div id="divLayer_6_3" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *안드로이드앱<br>*WiFi QR을 촬영하면 바로 접속이 가능함.<br>*WiFi 정보를 손쉽게 삭제할 수 있음.<br>
#         </div>
#     </div>
#     <div id="divLayer_6_4" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *교내 컴퓨터의 사양 등을 손쉽게 수집할 수 있음.<br>
#         </div>
#     </div>
#     <div id="divLayer_6_5" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *컴퓨터정보(이름, 작업그룹, 아이피 등..)을 손쉽게 바꿀 수 있음.<br>*매년 교실이 바뀐 학기초에 담임선생님께 보내 직접 수정하게 할 수 있도록 쉽게 사용할 수 있음.<br>
#         </div>
#     </div>
#     <div id="divLayer_6_6" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             *경력계산을 해주는 엑셀파일.<br>
#         </div>
#     </div>
#
#
#
#         <!--레이어 도움말-->
#         <div id="divLayer_7_1" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             .
#         </div>
#     </div>
#     <div id="divLayer_7_2" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             .
#         </div>
#     </div>
#     <div id="divLayer_7_3" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             .
#         </div>
#     </div>
#     <div id="divLayer_7_4" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             .
#         </div>
#     </div>
#     <div id="divLayer_7_5" class="overLayer" style="position: relative;">
#         <br>
#         <div class="content">
#             <strong><span id="content">제목</span></strong>
#             <br><br>
#             * 여름방학 부터 당분간 계속 쪼랩(인디스쿨 취미 코딩 커뮤니티)에서 라라벨(laravel) 공부중입니다. 그래서, 잠시 모든 개발을 멈추게 되어습니다. 추후 라라벨 공부가 끝나면 다시 취미 개발을 시작할 예정입니다.
#         </div>
#     </div>
#
#     <p align="center" style="position: relative;">&nbsp;</p>
#     <p align="center" style="position: relative;">&nbsp;</p>
#     <p align="center" style="position: relative;">&nbsp;</p>
#
#
#
# </body></html>
